# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirigalla34/deep-learning-programs/blob/main/sigmoid_activation_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
data = pd.read_csv("breast-cancer.csv")
if 'id' in data.columns:
    data = data.drop(columns=['id'])
data['diagnosis'] = data['diagnosis'].map({'B': 0, 'M': 1})
X = data.drop(columns=['diagnosis']).values
y = data['diagnosis'].values
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=42
)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))
class SigmoidClassifier:
    def __init__(self, lr=0.01, epochs=1000):
        self.lr = lr
        self.epochs = epochs
    def fit(self, X, y):
        self.w = np.zeros(X.shape[1])
        self.b = 0
        y = y.reshape(-1, 1)

        for _ in range(self.epochs):
            z = np.dot(X, self.w) + self.b
            y_pred = sigmoid(z)

            error = y.flatten() - y_pred
            self.w += self.lr * np.dot(X.T, error)
            self.b += self.lr * np.sum(error)

    def predict(self, X):
        z = np.dot(X, self.w) + self.b
        return (sigmoid(z) >= 0.5).astype(int)

model = SigmoidClassifier()
model.fit(X_train, y_train)

print("Sigmoid Model Train Accuracy:",
      accuracy_score(y_train, model.predict(X_train)))

print("Sigmoid Model Test Accuracy :",
      accuracy_score(y_test, model.predict(X_test)))
# Out:
# Sigmoid Model Train Accuracy: 0.9859154929577465
# Sigmoid Model Test Accuracy : 0.9649122807017544
