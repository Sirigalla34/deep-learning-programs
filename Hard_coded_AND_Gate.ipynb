# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirigalla34/deep-learning-programs/blob/main/Hard_coded_AND_Gate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[0],[0],[1]])

print("AND Gate Single Perceptron Hard Coded Weights")
print("="*60)

weights = np.array([[1.0],[1.0]])
bias = np.array([[-1.5]])

print(f"Weights: w1 = {weights[0,0]:.1f}, w2 = {weights[1,0]:.1f}")
print(f"Bias: b = {bias[0,0]:.1f}")

print(f"Equation: {weights[0,0]:.1f}*x1 + {weights[1,0]:.1f}*x2 + {bias[0,0]:.1f} > 0")

def step_function(x):
    return 1 if x > 0 else 0

def perceptron_predict(x, weights, bias):
    linear = np.dot(x, weights) + bias
    return (linear > 0).astype(int)

print("\nPredictions")

linear_values = np.dot(x, weights) + bias
predictions = perceptron_predict(x, weights, bias)

for i in range(len(x)):
    linear_val = linear_values[i,0]
    pred = predictions[i,0]
    actual = y[i,0]
    print(f"[{x[i,0]}, {x[i,1]}] -> linear={linear_val:.2f} -> pred={pred}")

actual = y.flatten()

plt.figure(figsize=(6,5))
plt.subplot(1,1,1)
plt.title("AND Gate Decision Boundary")

plt.scatter(x[actual==0][:,0], x[actual==0][:,1], c='red', marker='o')
plt.scatter(x[actual==1][:,0], x[actual==1][:,1], c='blue', marker='s')

plt.xlim(-0.3,1.3)
plt.ylim(-0.3,1.3)

plt.xlabel("Input x1")
plt.ylabel("Input x2")

x1_range = np.linspace(-0.3,1.3,200)
x2_boundary = -(weights[0,0]*x1_range + bias[0,0]) / weights[1,0]

plt.plot(x1_range, x2_boundary, 'g-', linewidth=2)

plt.fill_between(x1_range, x2_boundary, 1.3, color='blue', alpha=0.1)
plt.fill_between(x1_range, x2_boundary, -0.3, color='red', alpha=0.1)

plt.grid(True)
plt.show()

print("\nVerification Results")

for i in range(len(x)):
    z = weights[0,0]*x[i,0] + weights[1,0]*x[i,1] + bias[0,0]
    side = "Above class 1" if z > 0 else "Below class 0"
    print(f"[{x[i,0]}, {x[i,1]}] -> value={z:.2f} -> {side}")
# Out:
# AND Gate Single Perceptron Hard Coded Weights
# ...
# Weights: w1 = 1.0, w2 = 1.0
# Bias: b = -1.5
# Equation: 1.0*x1 + 1.0*x2 + -1.5 > 0
#
# Predictions
# [0, 0] -> linear=-1.50 -> pred=0
# [0, 1] -> linear=-0.50 -> pred=0
# [1, 0] -> linear=-0.50 -> pred=0
# [1, 1] -> linear=0.50 -> pred=1
# Verification Results
# [0, 0] -> value=-1.50 -> Below class 0
# [0, 1] -> value=-0.50 -> Below class 0
# [1, 0] -> value=-0.50 -> Below class 0
# [1, 1] -> value=0.50 -> Above class 1
